# %%
import pandas
from pandas import DataFrame
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pandas.read_csv('/content/titanic.csv')

# %%
data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data_np = np.loadtxt("/content/titanic.csv",
                 delimiter=",", dtype=str)
display(data_np)
# Out:
# array([['survived', 'pclass', 'sex', ..., 'fare', 'embarked', 'deck'],
#        ['0', '3', 'male', ..., '7.25', 'S', ''],
#        ['1', '1', 'female', ..., '71.2833', 'C', 'C'],
#        ...,
#        ['0', '3', 'female', ..., '23.45', 'S', ''],
#        ['1', '1', 'male', ..., '30.0', 'C', 'C'],
#        ['0', '3', 'male', ..., '7.75', 'Q', '']], dtype='<U8')

# %%
x=DataFrame(data, columns=['age'])
y=DataFrame(data, columns=['fare'])

# %%
plt.figure( figsize=(6,6) )
plt.scatter(x , y , alpha=0.3)
plt.title('age of fare people')
plt.xlabel('age')
plt.ylabel('fare pepole')
plt.show()
